# %%
from __future__ import print_function
# %load_ext autoreload
# %autoreload 2
import os
if not os.path.exists('plots/'):
    os.mkdir('plots')

from six.moves import cPickle
from collections import defaultdict, OrderedDict

import numpy as np
import keras.backend as K

import kde
import simplebinmi

import utils
trn, tst = utils.get_mnist()

# Which measure to plot
infoplane_measure = 'upper'
#infoplane_measure = 'bin'

DO_SAVE        = False    # Whether to save plots or just show them
DO_LOWER       = True    # (infoplane_measure == 'lower')   # Whether to compute lower bounds also
DO_BINNED      = True    #(infoplane_measure == 'bin')     # Whether to compute MI estimates based on binning

MAX_EPOCHS = 100     # Max number of epoch for which to compute mutual information measure
# MAX_EPOCHS = 1000
COLORBAR_MAX_EPOCHS = 100

# Directories from which to load saved layer activity
ARCH = '1024-20-20-20'
#ARCH = '20-20-20-20-20-20'
#ARCH = '32-28-24-20-16-12'
#ARCH = '32-28-24-20-16-12-8-8'
DIR_TEMPLATE = '%%s_%s'%ARCH

# Functions to return upper and lower bounds on entropy of layer activity
noise_variance = 1e-1                    # Added Gaussian noise variance
Klayer_activity = K.placeholder(ndim=2)  # Keras placeholder 
entropy_func_upper = K.function([Klayer_activity,], [kde.entropy_estimator_kl(Klayer_activity, noise_variance),])
entropy_func_lower = K.function([Klayer_activity,], [kde.entropy_estimator_bd(Klayer_activity, noise_variance),])


# nats to bits conversion factor
nats2bits = 1.0/np.log(2) 


# Save indexes of tests data for each of the output classes
saved_labelixs = {}
for i in range(10):
    saved_labelixs[i] = tst.y == i

labelprobs = np.mean(tst.Y, axis=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
PLOT_LAYERS    = None     # Which layers to plot.  If None, all saved layers are plotted 

# Data structure used to store results
measures = OrderedDict()
measures['relu'] = {}
measures['tanh'] = {}

# %% [markdown]
# Compute MI measures
# -----

# %%
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        print("Directory %s not found" % cur_dir)
        continue
        
    # Load files saved during each epoch, and compute MI measures of the activity in that epoch
    print('*** Doing %s ***' % cur_dir)
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        fname = cur_dir + "/" + epochfile
        with open(fname, 'rb') as f:
            d = cPickle.load(f)

        epoch = d['epoch']
        if epoch in measures[activation]: # Skip this epoch if its already been processed
            continue                      # this is a trick to allow us to rerun this cell multiple times)
            
        if epoch > MAX_EPOCHS:
            continue

        print("Doing", fname)
        
        num_layers = len(d['data']['activity_tst'])

        if PLOT_LAYERS is None:
            PLOT_LAYERS = []
            for lndx in range(num_layers):
                #if d['data']['activity_tst'][lndx].shape[1] < 200 and lndx != num_layers - 1:
                PLOT_LAYERS.append(lndx)
                
        cepochdata = defaultdict(list)
        for lndx in range(num_layers):
            activity = d['data']['activity_tst'][lndx]

            # Compute marginal entropies
            h_upper = entropy_func_upper([activity,])[0]
            if DO_LOWER:
                h_lower = entropy_func_lower([activity,])[0]
                
            # Layer activity given input. This is simply the entropy of the Gaussian noise
            hM_given_X = kde.kde_condentropy(activity, noise_variance)

            # Compute conditional entropies of layer activity given output
            hM_given_Y_upper=0.
            for i in range(10):
                hcond_upper = entropy_func_upper([activity[saved_labelixs[i],:],])[0]
                hM_given_Y_upper += labelprobs[i] * hcond_upper
                
            if DO_LOWER:
                hM_given_Y_lower=0.
                for i in range(10):
                    hcond_lower = entropy_func_lower([activity[saved_labelixs[i],:],])[0]
                    hM_given_Y_lower += labelprobs[i] * hcond_lower
                    
                    
            # # It's also possible to treat the last layer probabilistically. Here is the 
            # # code to do so. Should only be applied when lndx == num_layers - 1

            # ps = activity.mean(axis=0)
            # h_lower = h_upper = sum([-p*np.log(p) for p in ps if p != 0])

            # x = -activity * np.log(activity)
            # x[activity == 0] = 0.
            # hM_given_X = np.mean(x.sum(axis=1))

            # hM_given_Y=0.
            # for i in range(10):
            #     ixs = tst.y[::subsample] == i
            #     ps = activity[ixs,:].mean(axis=0)
            #     hcond = sum([-p*np.log(p) for p in ps if p != 0])
            #     prob = np.mean(ixs)
            #     hM_given_Y += l * hcond
            # hM_given_Y_lower = hM_given_Y_upper = hM_given_Y
            # del hM_given_Y
                
            cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
            cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
            cepochdata['H_M_upper'  ].append( nats2bits * h_upper )

            pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1])
            if DO_LOWER:  # Compute lower bounds
                cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

            if DO_BINNED: # Compute binner estimates
                binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                cepochdata['MI_YM_bin'].append( nats2bits * binym )
                pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])
            
            print('- Layer %d %s' % (lndx, pstr) )

        measures[activation][epoch] = cepochdata
# Out:
# Directory rawdata/relu_1024-20-20-20 not found
# *** Doing rawdata/tanh_1024-20-20-20 ***
# Doing rawdata/tanh_1024-20-20-20/epoch00000000
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.694, MI(Y;M)=3.086 | lower: MI(X;M)=5.741, MI(Y;M)=1.823 | bin: MI(X;M)=13.215, MI(Y;M)=3.317
# - Layer 2 upper: MI(X;M)=10.509, MI(Y;M)=2.796 | lower: MI(X;M)=5.205, MI(Y;M)=1.764 | bin: MI(X;M)=13.110, MI(Y;M)=3.303
# - Layer 3 upper: MI(X;M)=8.954, MI(Y;M)=2.431 | lower: MI(X;M)=4.554, MI(Y;M)=1.691 | bin: MI(X;M)=12.764, MI(Y;M)=3.219
# - Layer 4 upper: MI(X;M)=0.535, MI(Y;M)=0.359 | lower: MI(X;M)=0.143, MI(Y;M)=0.097 | bin: MI(X;M)=-0.000, MI(Y;M)=-0.000
# Doing rawdata/tanh_1024-20-20-20/epoch00000001
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.894, MI(Y;M)=3.196 | lower: MI(X;M)=6.451, MI(Y;M)=2.212 | bin: MI(X;M)=13.195, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.738, MI(Y;M)=3.005 | lower: MI(X;M)=5.782, MI(Y;M)=2.133 | bin: MI(X;M)=13.077, MI(Y;M)=3.311
# - Layer 3 upper: MI(X;M)=9.270, MI(Y;M)=2.732 | lower: MI(X;M)=5.075, MI(Y;M)=2.024 | bin: MI(X;M)=12.692, MI(Y;M)=3.253
# - Layer 4 upper: MI(X;M)=0.885, MI(Y;M)=0.629 | lower: MI(X;M)=0.245, MI(Y;M)=0.178 | bin: MI(X;M)=0.151, MI(Y;M)=0.064
# Doing rawdata/tanh_1024-20-20-20/epoch00000002
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.970, MI(Y;M)=3.236 | lower: MI(X;M)=6.823, MI(Y;M)=2.398 | bin: MI(X;M)=13.213, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.804, MI(Y;M)=3.086 | lower: MI(X;M)=6.065, MI(Y;M)=2.314 | bin: MI(X;M)=13.017, MI(Y;M)=3.312
# - Layer 3 upper: MI(X;M)=9.440, MI(Y;M)=2.871 | lower: MI(X;M)=5.385, MI(Y;M)=2.210 | bin: MI(X;M)=12.618, MI(Y;M)=3.271
# - Layer 4 upper: MI(X;M)=1.179, MI(Y;M)=0.857 | lower: MI(X;M)=0.339, MI(Y;M)=0.252 | bin: MI(X;M)=0.645, MI(Y;M)=0.392
# Doing rawdata/tanh_1024-20-20-20/epoch00000003
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.012, MI(Y;M)=3.258 | lower: MI(X;M)=7.062, MI(Y;M)=2.516 | bin: MI(X;M)=13.221, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.836, MI(Y;M)=3.133 | lower: MI(X;M)=6.243, MI(Y;M)=2.429 | bin: MI(X;M)=12.976, MI(Y;M)=3.313
# - Layer 3 upper: MI(X;M)=9.550, MI(Y;M)=2.953 | lower: MI(X;M)=5.598, MI(Y;M)=2.334 | bin: MI(X;M)=12.602, MI(Y;M)=3.282
# - Layer 4 upper: MI(X;M)=1.439, MI(Y;M)=1.061 | lower: MI(X;M)=0.428, MI(Y;M)=0.324 | bin: MI(X;M)=1.022, MI(Y;M)=0.657
# Doing rawdata/tanh_1024-20-20-20/epoch00000004
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.037, MI(Y;M)=3.271 | lower: MI(X;M)=7.238, MI(Y;M)=2.599 | bin: MI(X;M)=13.228, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.855, MI(Y;M)=3.164 | lower: MI(X;M)=6.376, MI(Y;M)=2.514 | bin: MI(X;M)=12.942, MI(Y;M)=3.314
# - Layer 3 upper: MI(X;M)=9.630, MI(Y;M)=3.010 | lower: MI(X;M)=5.758, MI(Y;M)=2.427 | bin: MI(X;M)=12.616, MI(Y;M)=3.289
# - Layer 4 upper: MI(X;M)=1.672, MI(Y;M)=1.244 | lower: MI(X;M)=0.514, MI(Y;M)=0.395 | bin: MI(X;M)=1.391, MI(Y;M)=0.918
# Doing rawdata/tanh_1024-20-20-20/epoch00000005
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.054, MI(Y;M)=3.280 | lower: MI(X;M)=7.372, MI(Y;M)=2.662 | bin: MI(X;M)=13.224, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.863, MI(Y;M)=3.186 | lower: MI(X;M)=6.474, MI(Y;M)=2.580 | bin: MI(X;M)=12.911, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.686, MI(Y;M)=3.051 | lower: MI(X;M)=5.880, MI(Y;M)=2.500 | bin: MI(X;M)=12.632, MI(Y;M)=3.296
# - Layer 4 upper: MI(X;M)=1.868, MI(Y;M)=1.401 | lower: MI(X;M)=0.591, MI(Y;M)=0.460 | bin: MI(X;M)=1.604, MI(Y;M)=1.105
# Doing rawdata/tanh_1024-20-20-20/epoch00000006
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.320 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.070, MI(Y;M)=3.287 | lower: MI(X;M)=7.486, MI(Y;M)=2.714 | bin: MI(X;M)=13.214, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.875, MI(Y;M)=3.202 | lower: MI(X;M)=6.557, MI(Y;M)=2.635 | bin: MI(X;M)=12.894, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.737, MI(Y;M)=3.084 | lower: MI(X;M)=5.983, MI(Y;M)=2.562 | bin: MI(X;M)=12.633, MI(Y;M)=3.297
# - Layer 4 upper: MI(X;M)=2.039, MI(Y;M)=1.539 | lower: MI(X;M)=0.664, MI(Y;M)=0.522 | bin: MI(X;M)=1.767, MI(Y;M)=1.244
# Doing rawdata/tanh_1024-20-20-20/epoch00000007
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.085, MI(Y;M)=3.292 | lower: MI(X;M)=7.588, MI(Y;M)=2.756 | bin: MI(X;M)=13.212, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.889, MI(Y;M)=3.217 | lower: MI(X;M)=6.633, MI(Y;M)=2.681 | bin: MI(X;M)=12.891, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.784, MI(Y;M)=3.112 | lower: MI(X;M)=6.076, MI(Y;M)=2.615 | bin: MI(X;M)=12.630, MI(Y;M)=3.300
# - Layer 4 upper: MI(X;M)=2.195, MI(Y;M)=1.666 | lower: MI(X;M)=0.734, MI(Y;M)=0.582 | bin: MI(X;M)=1.903, MI(Y;M)=1.356
# Doing rawdata/tanh_1024-20-20-20/epoch00000008
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.098, MI(Y;M)=3.296 | lower: MI(X;M)=7.676, MI(Y;M)=2.791 | bin: MI(X;M)=13.208, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.900, MI(Y;M)=3.228 | lower: MI(X;M)=6.697, MI(Y;M)=2.719 | bin: MI(X;M)=12.881, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.821, MI(Y;M)=3.133 | lower: MI(X;M)=6.154, MI(Y;M)=2.661 | bin: MI(X;M)=12.590, MI(Y;M)=3.304
# - Layer 4 upper: MI(X;M)=2.332, MI(Y;M)=1.777 | lower: MI(X;M)=0.800, MI(Y;M)=0.638 | bin: MI(X;M)=2.088, MI(Y;M)=1.484
# Doing rawdata/tanh_1024-20-20-20/epoch00000009
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.113, MI(Y;M)=3.299 | lower: MI(X;M)=7.752, MI(Y;M)=2.821 | bin: MI(X;M)=13.205, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.914, MI(Y;M)=3.237 | lower: MI(X;M)=6.752, MI(Y;M)=2.752 | bin: MI(X;M)=12.875, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=9.860, MI(Y;M)=3.151 | lower: MI(X;M)=6.225, MI(Y;M)=2.702 | bin: MI(X;M)=12.588, MI(Y;M)=3.306
# - Layer 4 upper: MI(X;M)=2.454, MI(Y;M)=1.876 | lower: MI(X;M)=0.860, MI(Y;M)=0.690 | bin: MI(X;M)=2.309, MI(Y;M)=1.627
# Doing rawdata/tanh_1024-20-20-20/epoch00000010
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.123, MI(Y;M)=3.301 | lower: MI(X;M)=7.821, MI(Y;M)=2.845 | bin: MI(X;M)=13.193, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.922, MI(Y;M)=3.244 | lower: MI(X;M)=6.801, MI(Y;M)=2.780 | bin: MI(X;M)=12.882, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.889, MI(Y;M)=3.165 | lower: MI(X;M)=6.286, MI(Y;M)=2.735 | bin: MI(X;M)=12.560, MI(Y;M)=3.309
# - Layer 4 upper: MI(X;M)=2.565, MI(Y;M)=1.967 | lower: MI(X;M)=0.918, MI(Y;M)=0.741 | bin: MI(X;M)=2.521, MI(Y;M)=1.767
# Doing rawdata/tanh_1024-20-20-20/epoch00000011
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.136, MI(Y;M)=3.303 | lower: MI(X;M)=7.885, MI(Y;M)=2.867 | bin: MI(X;M)=13.190, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.934, MI(Y;M)=3.250 | lower: MI(X;M)=6.847, MI(Y;M)=2.804 | bin: MI(X;M)=12.882, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.918, MI(Y;M)=3.178 | lower: MI(X;M)=6.343, MI(Y;M)=2.765 | bin: MI(X;M)=12.539, MI(Y;M)=3.310
# - Layer 4 upper: MI(X;M)=2.669, MI(Y;M)=2.051 | lower: MI(X;M)=0.974, MI(Y;M)=0.790 | bin: MI(X;M)=2.701, MI(Y;M)=1.891
# Doing rawdata/tanh_1024-20-20-20/epoch00000012
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.144, MI(Y;M)=3.305 | lower: MI(X;M)=7.942, MI(Y;M)=2.886 | bin: MI(X;M)=13.182, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.943, MI(Y;M)=3.256 | lower: MI(X;M)=6.889, MI(Y;M)=2.825 | bin: MI(X;M)=12.878, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=9.944, MI(Y;M)=3.189 | lower: MI(X;M)=6.396, MI(Y;M)=2.791 | bin: MI(X;M)=12.502, MI(Y;M)=3.308
# - Layer 4 upper: MI(X;M)=2.761, MI(Y;M)=2.126 | lower: MI(X;M)=1.028, MI(Y;M)=0.837 | bin: MI(X;M)=2.857, MI(Y;M)=2.005
# Doing rawdata/tanh_1024-20-20-20/epoch00000013
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.152, MI(Y;M)=3.306 | lower: MI(X;M)=7.993, MI(Y;M)=2.902 | bin: MI(X;M)=13.173, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.950, MI(Y;M)=3.261 | lower: MI(X;M)=6.925, MI(Y;M)=2.843 | bin: MI(X;M)=12.869, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=9.964, MI(Y;M)=3.198 | lower: MI(X;M)=6.440, MI(Y;M)=2.813 | bin: MI(X;M)=12.489, MI(Y;M)=3.307
# - Layer 4 upper: MI(X;M)=2.847, MI(Y;M)=2.196 | lower: MI(X;M)=1.080, MI(Y;M)=0.883 | bin: MI(X;M)=2.976, MI(Y;M)=2.092
# Doing rawdata/tanh_1024-20-20-20/epoch00000014
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.164, MI(Y;M)=3.307 | lower: MI(X;M)=8.039, MI(Y;M)=2.917 | bin: MI(X;M)=13.174, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.960, MI(Y;M)=3.264 | lower: MI(X;M)=6.957, MI(Y;M)=2.859 | bin: MI(X;M)=12.865, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=9.985, MI(Y;M)=3.205 | lower: MI(X;M)=6.481, MI(Y;M)=2.834 | bin: MI(X;M)=12.474, MI(Y;M)=3.308
# - Layer 4 upper: MI(X;M)=2.924, MI(Y;M)=2.257 | lower: MI(X;M)=1.128, MI(Y;M)=0.925 | bin: MI(X;M)=3.087, MI(Y;M)=2.177
# Doing rawdata/tanh_1024-20-20-20/epoch00000015
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.173, MI(Y;M)=3.308 | lower: MI(X;M)=8.081, MI(Y;M)=2.929 | bin: MI(X;M)=13.174, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.968, MI(Y;M)=3.267 | lower: MI(X;M)=6.984, MI(Y;M)=2.873 | bin: MI(X;M)=12.859, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.000, MI(Y;M)=3.211 | lower: MI(X;M)=6.515, MI(Y;M)=2.851 | bin: MI(X;M)=12.441, MI(Y;M)=3.308
# - Layer 4 upper: MI(X;M)=2.992, MI(Y;M)=2.312 | lower: MI(X;M)=1.173, MI(Y;M)=0.965 | bin: MI(X;M)=3.172, MI(Y;M)=2.249
# Doing rawdata/tanh_1024-20-20-20/epoch00000016
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.178, MI(Y;M)=3.308 | lower: MI(X;M)=8.120, MI(Y;M)=2.941 | bin: MI(X;M)=13.171, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.975, MI(Y;M)=3.270 | lower: MI(X;M)=7.013, MI(Y;M)=2.887 | bin: MI(X;M)=12.850, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.014, MI(Y;M)=3.217 | lower: MI(X;M)=6.548, MI(Y;M)=2.867 | bin: MI(X;M)=12.414, MI(Y;M)=3.308
# - Layer 4 upper: MI(X;M)=3.056, MI(Y;M)=2.364 | lower: MI(X;M)=1.219, MI(Y;M)=1.006 | bin: MI(X;M)=3.228, MI(Y;M)=2.293
# Doing rawdata/tanh_1024-20-20-20/epoch00000017
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.187, MI(Y;M)=3.309 | lower: MI(X;M)=8.155, MI(Y;M)=2.952 | bin: MI(X;M)=13.168, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.983, MI(Y;M)=3.273 | lower: MI(X;M)=7.038, MI(Y;M)=2.898 | bin: MI(X;M)=12.848, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.031, MI(Y;M)=3.222 | lower: MI(X;M)=6.579, MI(Y;M)=2.881 | bin: MI(X;M)=12.414, MI(Y;M)=3.310
# - Layer 4 upper: MI(X;M)=3.112, MI(Y;M)=2.409 | lower: MI(X;M)=1.260, MI(Y;M)=1.043 | bin: MI(X;M)=3.274, MI(Y;M)=2.342
# Doing rawdata/tanh_1024-20-20-20/epoch00000018
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.193, MI(Y;M)=3.310 | lower: MI(X;M)=8.188, MI(Y;M)=2.961 | bin: MI(X;M)=13.160, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.989, MI(Y;M)=3.276 | lower: MI(X;M)=7.061, MI(Y;M)=2.908 | bin: MI(X;M)=12.841, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.042, MI(Y;M)=3.227 | lower: MI(X;M)=6.607, MI(Y;M)=2.893 | bin: MI(X;M)=12.394, MI(Y;M)=3.310
# - Layer 4 upper: MI(X;M)=3.164, MI(Y;M)=2.451 | lower: MI(X;M)=1.302, MI(Y;M)=1.080 | bin: MI(X;M)=3.312, MI(Y;M)=2.385
# Doing rawdata/tanh_1024-20-20-20/epoch00000019
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.198, MI(Y;M)=3.310 | lower: MI(X;M)=8.214, MI(Y;M)=2.970 | bin: MI(X;M)=13.157, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.992, MI(Y;M)=3.277 | lower: MI(X;M)=7.078, MI(Y;M)=2.918 | bin: MI(X;M)=12.846, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.050, MI(Y;M)=3.231 | lower: MI(X;M)=6.628, MI(Y;M)=2.905 | bin: MI(X;M)=12.386, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.208, MI(Y;M)=2.487 | lower: MI(X;M)=1.339, MI(Y;M)=1.113 | bin: MI(X;M)=3.343, MI(Y;M)=2.423
# Doing rawdata/tanh_1024-20-20-20/epoch00000020
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.205, MI(Y;M)=3.311 | lower: MI(X;M)=8.245, MI(Y;M)=2.978 | bin: MI(X;M)=13.155, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.001, MI(Y;M)=3.279 | lower: MI(X;M)=7.100, MI(Y;M)=2.927 | bin: MI(X;M)=12.841, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.061, MI(Y;M)=3.234 | lower: MI(X;M)=6.651, MI(Y;M)=2.915 | bin: MI(X;M)=12.379, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.250, MI(Y;M)=2.521 | lower: MI(X;M)=1.376, MI(Y;M)=1.147 | bin: MI(X;M)=3.363, MI(Y;M)=2.457
# Doing rawdata/tanh_1024-20-20-20/epoch00000025
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.229, MI(Y;M)=3.312 | lower: MI(X;M)=8.356, MI(Y;M)=3.011 | bin: MI(X;M)=13.141, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.023, MI(Y;M)=3.287 | lower: MI(X;M)=7.175, MI(Y;M)=2.963 | bin: MI(X;M)=12.820, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.094, MI(Y;M)=3.249 | lower: MI(X;M)=6.734, MI(Y;M)=2.957 | bin: MI(X;M)=12.325, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.399, MI(Y;M)=2.644 | lower: MI(X;M)=1.535, MI(Y;M)=1.292 | bin: MI(X;M)=3.424, MI(Y;M)=2.561
# Doing rawdata/tanh_1024-20-20-20/epoch00000030
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.247, MI(Y;M)=3.313 | lower: MI(X;M)=8.439, MI(Y;M)=3.035 | bin: MI(X;M)=13.126, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.039, MI(Y;M)=3.292 | lower: MI(X;M)=7.229, MI(Y;M)=2.990 | bin: MI(X;M)=12.816, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.117, MI(Y;M)=3.259 | lower: MI(X;M)=6.792, MI(Y;M)=2.986 | bin: MI(X;M)=12.266, MI(Y;M)=3.313
# - Layer 4 upper: MI(X;M)=3.482, MI(Y;M)=2.718 | lower: MI(X;M)=1.658, MI(Y;M)=1.407 | bin: MI(X;M)=3.441, MI(Y;M)=2.612
# Doing rawdata/tanh_1024-20-20-20/epoch00000035
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.264, MI(Y;M)=3.314 | lower: MI(X;M)=8.503, MI(Y;M)=3.054 | bin: MI(X;M)=13.118, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.050, MI(Y;M)=3.296 | lower: MI(X;M)=7.267, MI(Y;M)=3.010 | bin: MI(X;M)=12.816, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.125, MI(Y;M)=3.266 | lower: MI(X;M)=6.827, MI(Y;M)=3.009 | bin: MI(X;M)=12.208, MI(Y;M)=3.314
# - Layer 4 upper: MI(X;M)=3.530, MI(Y;M)=2.766 | lower: MI(X;M)=1.753, MI(Y;M)=1.498 | bin: MI(X;M)=3.449, MI(Y;M)=2.646
# Doing rawdata/tanh_1024-20-20-20/epoch00000040
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.276, MI(Y;M)=3.315 | lower: MI(X;M)=8.558, MI(Y;M)=3.069 | bin: MI(X;M)=13.122, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.058, MI(Y;M)=3.298 | lower: MI(X;M)=7.299, MI(Y;M)=3.027 | bin: MI(X;M)=12.806, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.131, MI(Y;M)=3.272 | lower: MI(X;M)=6.856, MI(Y;M)=3.028 | bin: MI(X;M)=12.182, MI(Y;M)=3.315
# - Layer 4 upper: MI(X;M)=3.558, MI(Y;M)=2.800 | lower: MI(X;M)=1.829, MI(Y;M)=1.573 | bin: MI(X;M)=3.451, MI(Y;M)=2.675
# Doing rawdata/tanh_1024-20-20-20/epoch00000045
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.289, MI(Y;M)=3.315 | lower: MI(X;M)=8.608, MI(Y;M)=3.081 | bin: MI(X;M)=13.127, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.067, MI(Y;M)=3.300 | lower: MI(X;M)=7.327, MI(Y;M)=3.041 | bin: MI(X;M)=12.797, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.131, MI(Y;M)=3.276 | lower: MI(X;M)=6.876, MI(Y;M)=3.044 | bin: MI(X;M)=12.133, MI(Y;M)=3.314
# - Layer 4 upper: MI(X;M)=3.574, MI(Y;M)=2.825 | lower: MI(X;M)=1.891, MI(Y;M)=1.634 | bin: MI(X;M)=3.450, MI(Y;M)=2.703
# Doing rawdata/tanh_1024-20-20-20/epoch00000050
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.297, MI(Y;M)=3.316 | lower: MI(X;M)=8.647, MI(Y;M)=3.090 | bin: MI(X;M)=13.126, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.071, MI(Y;M)=3.302 | lower: MI(X;M)=7.349, MI(Y;M)=3.052 | bin: MI(X;M)=12.797, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.134, MI(Y;M)=3.280 | lower: MI(X;M)=6.894, MI(Y;M)=3.057 | bin: MI(X;M)=12.124, MI(Y;M)=3.314
# - Layer 4 upper: MI(X;M)=3.583, MI(Y;M)=2.845 | lower: MI(X;M)=1.941, MI(Y;M)=1.686 | bin: MI(X;M)=3.448, MI(Y;M)=2.726
# Doing rawdata/tanh_1024-20-20-20/epoch00000055
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.306, MI(Y;M)=3.316 | lower: MI(X;M)=8.682, MI(Y;M)=3.099 | bin: MI(X;M)=13.124, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.078, MI(Y;M)=3.303 | lower: MI(X;M)=7.368, MI(Y;M)=3.061 | bin: MI(X;M)=12.794, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.139, MI(Y;M)=3.283 | lower: MI(X;M)=6.910, MI(Y;M)=3.068 | bin: MI(X;M)=12.092, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.589, MI(Y;M)=2.862 | lower: MI(X;M)=1.983, MI(Y;M)=1.729 | bin: MI(X;M)=3.446, MI(Y;M)=2.743
# Doing rawdata/tanh_1024-20-20-20/epoch00000060
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.309, MI(Y;M)=3.316 | lower: MI(X;M)=8.707, MI(Y;M)=3.105 | bin: MI(X;M)=13.120, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.076, MI(Y;M)=3.304 | lower: MI(X;M)=7.379, MI(Y;M)=3.069 | bin: MI(X;M)=12.783, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.134, MI(Y;M)=3.285 | lower: MI(X;M)=6.917, MI(Y;M)=3.078 | bin: MI(X;M)=12.074, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.591, MI(Y;M)=2.876 | lower: MI(X;M)=2.018, MI(Y;M)=1.767 | bin: MI(X;M)=3.443, MI(Y;M)=2.757
# Doing rawdata/tanh_1024-20-20-20/epoch00000065
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.320, MI(Y;M)=3.316 | lower: MI(X;M)=8.742, MI(Y;M)=3.111 | bin: MI(X;M)=13.118, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.089, MI(Y;M)=3.305 | lower: MI(X;M)=7.398, MI(Y;M)=3.077 | bin: MI(X;M)=12.795, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.139, MI(Y;M)=3.287 | lower: MI(X;M)=6.929, MI(Y;M)=3.087 | bin: MI(X;M)=12.070, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.591, MI(Y;M)=2.886 | lower: MI(X;M)=2.047, MI(Y;M)=1.798 | bin: MI(X;M)=3.440, MI(Y;M)=2.766
# Doing rawdata/tanh_1024-20-20-20/epoch00000070
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.321, MI(Y;M)=3.316 | lower: MI(X;M)=8.762, MI(Y;M)=3.116 | bin: MI(X;M)=13.107, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.088, MI(Y;M)=3.305 | lower: MI(X;M)=7.409, MI(Y;M)=3.083 | bin: MI(X;M)=12.784, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.140, MI(Y;M)=3.289 | lower: MI(X;M)=6.940, MI(Y;M)=3.095 | bin: MI(X;M)=12.065, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.591, MI(Y;M)=2.897 | lower: MI(X;M)=2.073, MI(Y;M)=1.827 | bin: MI(X;M)=3.438, MI(Y;M)=2.775
# Doing rawdata/tanh_1024-20-20-20/epoch00000075
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.328, MI(Y;M)=3.316 | lower: MI(X;M)=8.791, MI(Y;M)=3.121 | bin: MI(X;M)=13.103, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.099, MI(Y;M)=3.306 | lower: MI(X;M)=7.427, MI(Y;M)=3.089 | bin: MI(X;M)=12.785, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.149, MI(Y;M)=3.290 | lower: MI(X;M)=6.954, MI(Y;M)=3.102 | bin: MI(X;M)=12.056, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.590, MI(Y;M)=2.906 | lower: MI(X;M)=2.096, MI(Y;M)=1.852 | bin: MI(X;M)=3.435, MI(Y;M)=2.786
# Doing rawdata/tanh_1024-20-20-20/epoch00000080
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.333, MI(Y;M)=3.316 | lower: MI(X;M)=8.810, MI(Y;M)=3.125 | bin: MI(X;M)=13.097, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.104, MI(Y;M)=3.306 | lower: MI(X;M)=7.436, MI(Y;M)=3.094 | bin: MI(X;M)=12.787, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.154, MI(Y;M)=3.291 | lower: MI(X;M)=6.962, MI(Y;M)=3.108 | bin: MI(X;M)=12.077, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.588, MI(Y;M)=2.913 | lower: MI(X;M)=2.115, MI(Y;M)=1.874 | bin: MI(X;M)=3.432, MI(Y;M)=2.797
# Doing rawdata/tanh_1024-20-20-20/epoch00000085
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.332, MI(Y;M)=3.316 | lower: MI(X;M)=8.827, MI(Y;M)=3.128 | bin: MI(X;M)=13.084, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.105, MI(Y;M)=3.307 | lower: MI(X;M)=7.445, MI(Y;M)=3.098 | bin: MI(X;M)=12.781, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.150, MI(Y;M)=3.292 | lower: MI(X;M)=6.967, MI(Y;M)=3.114 | bin: MI(X;M)=12.065, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.586, MI(Y;M)=2.922 | lower: MI(X;M)=2.133, MI(Y;M)=1.895 | bin: MI(X;M)=3.432, MI(Y;M)=2.811
# Doing rawdata/tanh_1024-20-20-20/epoch00000090
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.340, MI(Y;M)=3.317 | lower: MI(X;M)=8.845, MI(Y;M)=3.130 | bin: MI(X;M)=13.081, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.118, MI(Y;M)=3.307 | lower: MI(X;M)=7.455, MI(Y;M)=3.102 | bin: MI(X;M)=12.785, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.164, MI(Y;M)=3.293 | lower: MI(X;M)=6.978, MI(Y;M)=3.119 | bin: MI(X;M)=12.092, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.584, MI(Y;M)=2.928 | lower: MI(X;M)=2.147, MI(Y;M)=1.911 | bin: MI(X;M)=3.430, MI(Y;M)=2.817
# Doing rawdata/tanh_1024-20-20-20/epoch00000095
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.319 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.339, MI(Y;M)=3.317 | lower: MI(X;M)=8.860, MI(Y;M)=3.133 | bin: MI(X;M)=13.076, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.119, MI(Y;M)=3.307 | lower: MI(X;M)=7.464, MI(Y;M)=3.106 | bin: MI(X;M)=12.781, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.163, MI(Y;M)=3.294 | lower: MI(X;M)=6.986, MI(Y;M)=3.124 | bin: MI(X;M)=12.081, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.581, MI(Y;M)=2.934 | lower: MI(X;M)=2.162, MI(Y;M)=1.929 | bin: MI(X;M)=3.430, MI(Y;M)=2.825

# %% [markdown]
# Plot overall summaries
# ----
#
# This is more for diagnostic purposes, not for article

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_style('darkgrid')


#PLOT_LAYERS = [0,1,2,3,4] # [1,2,3]
#PLOT_LAYERS = [0,1,2,3]
#PLOT_LAYERS = [0,1,2,3]
plt.figure(figsize=(8,8))
gs = gridspec.GridSpec(4,2)
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
        
    plt.subplot(gs[0,actndx])
    for lndx, layerid in enumerate(PLOT_LAYERS):
        xmvalsU = np.array([vals[epoch]['H_M_upper'][layerid] for epoch in epochs])
        if DO_LOWER:
            xmvalsL = np.array([vals[epoch]['H_M_lower'][layerid] for epoch in epochs])
        plt.plot(epochs, xmvalsU, label='Layer %d'%layerid)
        #plt.errorbar(epochs, (xmvalsL + xmvalsU)/2,xmvalsU - xmvalsL, label='Layer %d'%layerid)
    plt.xscale('log')
    plt.yscale('log')
    plt.title(activation)
    plt.ylabel('H(M)')
    
    plt.subplot(gs[1,actndx])
    for lndx, layerid in enumerate(PLOT_LAYERS):
        #for epoch in epochs:
        #    print('her',epoch, measures[activation][epoch]['MI_XM_upper'])
        xmvalsU = np.array([vals[epoch]['MI_XM_upper'][layerid] for epoch in epochs])
        if DO_LOWER:
            xmvalsL = np.array([vals[epoch]['MI_XM_lower'][layerid] for epoch in epochs])
        plt.plot(epochs, xmvalsU, label='Layer %d'%layerid)
        #plt.errorbar(epochs, (xmvalsL + xmvalsU)/2,xmvalsU - xmvalsL, label='Layer %d'%layerid)
    plt.xscale('log')
    plt.ylabel('I(X;M)')


    plt.subplot(gs[2,actndx])
    for lndx, layerid in enumerate(PLOT_LAYERS):
        ymvalsU = np.array([vals[epoch]['MI_YM_upper'][layerid] for epoch in epochs])
        if DO_LOWER:
            ymvalsL = np.array([vals[epoch]['MI_YM_lower'][layerid] for epoch in epochs])
        plt.plot(epochs, ymvalsU, label='Layer %d'%layerid)
    plt.xscale('log')
    plt.ylabel('MI(Y;M)')

    if DO_BINNED:
        plt.subplot(gs[3,actndx])
        for lndx, layerid in enumerate(PLOT_LAYERS):
            hbinnedvals = np.array([vals[epoch]['MI_XM_bin'][layerid] for epoch in epochs])
            plt.semilogx(epochs, hbinnedvals, label='Layer %d'%layerid)
        plt.xlabel('Epoch')
        plt.ylabel("I(X;M)bin")
    
    if actndx == 0:
        plt.legend(loc='lower right')
        
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib.gridspec as gridspec
# ----> 4 import seaborn as sns
#       5 sns.set_style('darkgrid')
#       8 #PLOT_LAYERS = [0,1,2,3,4] # [1,2,3]
#       9 #PLOT_LAYERS = [0,1,2,3]
#      10 #PLOT_LAYERS = [0,1,2,3]
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# Plot Infoplane Visualization
# ----

# %%
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
sm = plt.cm.ScalarMappable(cmap='gnuplot', norm=plt.Normalize(vmin=0, vmax=COLORBAR_MAX_EPOCHS))
sm._A = []

fig=plt.figure(figsize=(10,5))
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
    plt.subplot(1,2,actndx+1)    
    for epoch in epochs:
        c = sm.to_rgba(epoch)
        xmvals = np.array(vals[epoch]['MI_XM_'+infoplane_measure])[PLOT_LAYERS]
        ymvals = np.array(vals[epoch]['MI_YM_'+infoplane_measure])[PLOT_LAYERS]

        plt.plot(xmvals, ymvals, c=c, alpha=0.1, zorder=1)
        plt.scatter(xmvals, ymvals, s=20, facecolors=[c for _ in PLOT_LAYERS], edgecolor='none', zorder=2)
    
    plt.ylim([0, 3.5])
    plt.xlim([0, 14])
    plt.xlabel('I(X;M)')
    plt.ylabel('I(Y;M)')
    plt.title(activation)
    
cbaxes = fig.add_axes([1.0, 0.125, 0.03, 0.8]) 
plt.colorbar(sm, label='Epoch', cax=cbaxes)
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('infoplane_'+ARCH),bbox_inches='tight')
# Out:
# C:\Users\Omar\AppData\Local\Temp\ipykernel_17768\684448324.py:27: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# Plot SNR curves
# ----

# %%
plt.figure(figsize=(12,5))

gs = gridspec.GridSpec(len(measures), len(PLOT_LAYERS))
saved_data = {}
for actndx, activation in enumerate(measures.keys()):
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        continue
        
    epochs = []
    means = []
    stds = []
    wnorms = []
    trnloss = []
    tstloss = []
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        with open(cur_dir + "/"+epochfile, 'rb') as f:
            try:
                d = cPickle.load(f)
            except:
                print('Error loading ', epochfile)
                continue
            
        epoch = d['epoch']
        epochs.append(epoch)
        wnorms.append(d['data']['weights_norm'])
        means.append(d['data']['gradmean'])
        stds.append(d['data']['gradstd'])
        trnloss.append(d['loss']['trn'])
        tstloss.append(d['loss']['tst'])

    wnorms, means, stds, trnloss, tstloss = map(np.array, [wnorms, means, stds, trnloss, tstloss])
    saved_data[activation] = {'epochs':epochs, 'wnorms':wnorms, 'means': means, 'stds': stds, 'trnloss': trnloss, 'tstloss':tstloss}
    
    
    for lndx,layerid in enumerate(PLOT_LAYERS):
        plt.subplot(gs[actndx, lndx])
        plt.plot(epochs, means[:,layerid], 'b', label="Mean")
        plt.plot(epochs, stds[:,layerid], 'orange', label="Std")
        plt.plot(epochs, means[:,layerid]/stds[:,layerid], 'red', label="SNR")
        plt.plot(epochs, wnorms[:,layerid], 'g', label="||W||")

        plt.title('%s - Layer %d'%(activation, layerid))
        plt.xlabel('Epoch')
        plt.gca().set_xscale("log", nonposx='clip')
        plt.gca().set_yscale("log", nonposy='clip')
    

plt.legend(loc='lower left', bbox_to_anchor=(1.1, 0.2))
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('snr_'+ARCH), bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 48
#      46         plt.title('%s - Layer %d'%(activation, layerid))
#      47         plt.xlabel('Epoch')
# ---> 48         plt.gca().set_xscale("log", nonposx='clip')
#      49         plt.gca().set_yscale("log", nonposy='clip')
#      52 plt.legend(loc='lower left', bbox_to_anchor=(1.1, 0.2))
#
# File D:\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File D:\Lib\site-packages\matplotlib\axis.py:837, in Axis._set_axes_scale(self, value, **kwargs)
#     834 old_default_lims = (self.get_major_locator()
#     835                     .nonsingular(-np.inf, np.inf))
#     836 for ax in self._get_shared_axes():
# --> 837     ax._axis_map[name]._set_scale(value, **kwargs)
#     838     ax._update_transScale()
#     839     ax.stale = True
#
# File D:\Lib\site-packages\matplotlib\axis.py:796, in Axis._set_scale(self, value, **kwargs)
#     794 def _set_scale(self, value, **kwargs):
#     795     if not isinstance(value, mscale.ScaleBase):
# --> 796         self._scale = mscale.scale_factory(value, self, **kwargs)
#     797     else:
#     798         self._scale = value
#
# File D:\Lib\site-packages\matplotlib\scale.py:717, in scale_factory(scale, axis, **kwargs)
#     708 """
#     709 Return a scale class by name.
#     710
#    (...)
#     714 axis : `~matplotlib.axis.Axis`
#     715 """
#     716 scale_cls = _api.check_getitem(_scale_mapping, scale=scale)
# --> 717 return scale_cls(axis, **kwargs)
#
# TypeError: LogScale.__init__() got an unexpected keyword argument 'nonposx'

# %%
GRID_PLOT_LAYERS = [0,1,2,3] # [1,2,3]
sns.set_style('whitegrid')
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
H_X = np.log2(10000)
for actndx, (activation, vals) in enumerate(measures.items()):
    fig = plt.figure(figsize=(12,11))
    gs = gridspec.GridSpec(4, len(GRID_PLOT_LAYERS))
    
    cur_epochs = np.array(sorted(vals.keys()))
    if not len(cur_epochs):
        continue
    
    plt.subplot(gs[0,0])
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.plot(cur_epochs,saved_data[activation]['trnloss'][cur_epochs]/np.log(2), label='Train')
    plt.plot(cur_epochs,saved_data[activation]['tstloss'][cur_epochs]/np.log(2), label='Test')
    plt.ylabel('Cross entropy loss')
    plt.gca().set_xscale("log", nonposx='clip')
    
    plt.legend(loc='upper right', frameon=True)
        
    vals_binned = np.array([vals[epoch]['MI_XM_bin'] for epoch in cur_epochs])
    vals_lower = np.array([vals[epoch]['MI_XM_lower'] for epoch in cur_epochs])
    vals_upper = np.array([vals[epoch]['MI_XM_upper'] for epoch in cur_epochs])
    for layerndx, layerid in enumerate(GRID_PLOT_LAYERS):
        plt.subplot(gs[1,layerndx])
        plt.plot(cur_epochs, cur_epochs*0 + H_X, 'k:', label=r'$H(X)$')
        plt.fill_between(cur_epochs, vals_lower[cur_epochs,layerid], vals_upper[:,layerid])
        plt.gca().set_xscale("log", nonposx='clip')
        plt.ylim([0, 1.1*H_X])
        plt.title('Layer %d Mutual Info (KDE)'%(layerid+1))
        plt.ylabel(r'$I(X;T)$')
        plt.xlabel('Epoch')
        if layerndx == len(GRID_PLOT_LAYERS)-1:
            plt.legend(loc='lower right', frameon=True)
        
        plt.subplot(gs[2,layerndx])
        plt.plot(cur_epochs, cur_epochs*0 + H_X, 'k:', label=r'$H(X)$')
        plt.plot(cur_epochs, vals_binned[cur_epochs,layerid])
        plt.gca().set_xscale("log", nonposx='clip')
        plt.ylim([0, 1.1*H_X])
        plt.ylabel(r'$I(X;T)$')
        plt.title('Layer %d Mutual Info (binned)'%(layerid+1))
        plt.xlabel('Epoch')
        if layerndx == len(GRID_PLOT_LAYERS)-1:
            plt.legend(loc='lower right', frameon=True)
        
        plt.subplot(gs[3,layerndx])
        plt.title('Layer %d SNR'%(layerid+1))
        plt.plot(cur_epochs, saved_data[activation]['means' ][cur_epochs,layerid], 'b', label="Mean")
        plt.plot(cur_epochs, saved_data[activation]['stds'  ][cur_epochs,layerid], 'orange', label="Std")
        plt.plot(cur_epochs, saved_data[activation]['means' ][cur_epochs,layerid]/saved_data[activation]['stds'][cur_epochs,layerid], 'red', label="SNR")
        plt.plot(cur_epochs, saved_data[activation]['wnorms'][cur_epochs,layerid], 'g', label="||W||")

        plt.xlabel('Epoch')
        plt.gca().set_xscale("log", nonposx='clip')
        plt.gca().set_yscale("log", nonposy='clip')
    
    plt.tight_layout()
    plt.legend(loc='lower left', frameon=True)
    
    if DO_SAVE:
        plt.savefig('plots/' + DIR_TEMPLATE % ('gridplot_'+activation) + '.pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 GRID_PLOT_LAYERS = [0,1,2,3] # [1,2,3]
# ----> 2 sns.set_style('whitegrid')
#       3 max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
#       4 H_X = np.log2(10000)
#
# NameError: name 'sns' is not defined
